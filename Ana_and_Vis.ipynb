# %% [markdown]
# # Analysis and Visualization Basics

# %%
#Import required libraries
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
import folium

# %%
#Read the excel file
xl_file = pd.ExcelFile("https://www.dhhs.vic.gov.au/sites/default/files/documents/202108/Moving%20annual%20rents%20by%20suburb%20-%20June%20quarter%202021.xlsx")

# %% [markdown]
# ### Sheet 'All properties'

# %%
#From the excel file read the sheet called 'All properties'
df_all = pd.read_excel(xl_file, 'All properties')

# %%
df_all.head()
# Out:
#     All properties                             Unnamed: 1  \
# 0              NaN                                    NaN
# 1           Region                                 Suburb
# 2  Inner Melbourne  Albert Park-Middle Park-West St Kilda
# 3              NaN                               Armadale
# 4              NaN                          Carlton North
#
#   Lease commenced in year ending  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                        Mar 2000        NaN   Jun 2000        NaN   Sep 2000
# 1                           Count     Median      Count     Median      Count
# 2                            1146        260       1136        260       1177
# 3                             729        200        731        200        732
# 4                             864        260        814        260        800
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 164 Unnamed: 165  \
# 0        NaN   Dec 2000        NaN  ...     Jun 2020          NaN
# 1     Median      Count     Median  ...        Count       Median
# 2        270       1176        275  ...          826          585
# 3        205        732        210  ...          782          500
# 4        265        735        270  ...          536          590
#
#   Unnamed: 166 Unnamed: 167 Unnamed: 168 Unnamed: 169 Unnamed: 170  \
# 0     Sep 2020          NaN     Dec 2020          NaN     Mar 2021
# 1        Count       Median        Count       Median        Count
# 2          802          560          848          550          898
# 3          709          500          729          495          792
# 4          520          590          547          590          579
#
#   Unnamed: 171 Unnamed: 172 Unnamed: 173
# 0          NaN     Jun 2021          NaN
# 1       Median        Count       Median
# 2          500          932          500
# 3          450          813          440
# 4          580          598          580
#
# [5 rows x 174 columns]

# %%
#Save the dataframe as a '.csv' file
df_all.to_csv('All properties.csv')
#Save the dataframe as a '.json' file
df_all.to_json('All properties.json')

# %%
#Check the Null values in each column
df_all.isnull().sum()
# Out:
# All properties                     147
# Unnamed: 1                           1
# Lease commenced in year ending       0
# Unnamed: 3                           1
# Unnamed: 4                           0
#                                   ...
# Unnamed: 169                         1
# Unnamed: 170                         0
# Unnamed: 171                         1
# Unnamed: 172                         0
# Unnamed: 173                         1
# Length: 174, dtype: int64

# %%
#Check the rows and columns of the dataframe
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Columns: 174 entries, All properties to Unnamed: 173
# dtypes: object(174)
# memory usage: 219.0+ KB

# %%
#Since the headers are not named in the dataframe, creating a list for headers
columns = ['Region', 'Suburb']
for year in range (2000, 2022):
    columns.append('Mar '+str(year)+' Count')
    columns.append('Mar '+str(year)+' Median')
    columns.append('Jun '+str(year)+' Count')
    columns.append('Jun '+str(year)+' Median')
    columns.append('Sep '+str(year)+' Count')
    columns.append('Sep '+str(year)+' Median')
    columns.append('Dec '+str(year)+' Count')
    columns.append('Dec '+str(year)+' Median')
    
headers = columns[0:len(columns)-4]

# %%
#Remove the first two rows
df_all_new = df_all[2:]
#Assign the created list as headers
df_all_new.columns = headers
#Empty cells in the 'Region' columns are filled with NaN
#So remove the NaN values with ''
df_all_new = df_all_new.fillna('')

# %%
df_all_new.head(10)
# Out:
#              Region                                 Suburb Mar 2000 Count  \
# 2   Inner Melbourne  Albert Park-Middle Park-West St Kilda           1146
# 3                                                 Armadale            729
# 4                                            Carlton North            864
# 5                                        Carlton-Parkville           1344
# 6                                          CBD-St Kilda Rd           2138
# 7                                   Collingwood-Abbotsford            654
# 8                                                Docklands              -
# 9                                           East Melbourne            495
# 10                                           East St Kilda           1752
# 11                                                  Elwood           1738
#
#    Mar 2000 Median  Jun 2000 Count  Jun 2000 Median Sep 2000 Count  \
# 2              260            1136              260           1177
# 3              200             731              200            732
# 4              260             814              260            800
# 5              260            1312              260           1306
# 6              320            2269              320           2362
# 7              230             654              230            700
# 8                -              10              340              -
# 9              265             490              268            516
# 10             180            1726              180           1704
# 11             200            1668              200           1663
#
#    Sep 2000 Median Dec 2000 Count Dec 2000 Median  ... Jun 2020 Count  \
# 2              270           1176             275  ...            826
# 3              205            732             210  ...            782
# 4              265            735             270  ...            536
# 5              260           1322             260  ...           5025
# 6              320           2361             320  ...          11039
# 7              240            709             240  ...           1993
# 8                -              -               -  ...           2229
# 9              280            506             273  ...            629
# 10             180           1633             185  ...           1615
# 11             200           1696             210  ...           1557
#
#    Jun 2020 Median Sep 2020 Count Sep 2020 Median Dec 2020 Count  \
# 2              585            802             560            848
# 3              500            709             500            729
# 4              590            520             590            547
# 5              400           4633             400           4764
# 6              495          11325             460          13473
# 7              490           1990             480           2089
# 8              550           2475             500           3009
# 9              550            562             515            549
# 10             425           1597             420           1616
# 11             450           1533             450           1592
#
#    Dec 2020 Median Mar 2021 Count Mar 2021 Median  Jun 2021 Count  \
# 2              550            898             500             932
# 3              495            792             450             813
# 4              590            579             580             598
# 5              395           4170             350            4763
# 6              420          15630             380           17553
# 7              460           2329             450            2475
# 8              460           3515             420            3821
# 9              495            574             450             599
# 10             410           1685             395            1708
# 11             440           1673             425            1669
#
#     Jun 2021 Median
# 2               500
# 3               440
# 4               580
# 5               340
# 6               370
# 7               430
# 8               400
# 9               450
# 10              385
# 11              425
#
# [10 rows x 174 columns]

# %%
#Null values are indicated with '-'
#So replace the '-' with 'NaN'
df_all_new = df_all_new.replace('-', np.NaN)

# %%
df_all_new.head(10)
# Out:
#              Region                                 Suburb  Mar 2000 Count  \
# 2   Inner Melbourne  Albert Park-Middle Park-West St Kilda          1146.0
# 3                                                 Armadale           729.0
# 4                                            Carlton North           864.0
# 5                                        Carlton-Parkville          1344.0
# 6                                          CBD-St Kilda Rd          2138.0
# 7                                   Collingwood-Abbotsford           654.0
# 8                                                Docklands             NaN
# 9                                           East Melbourne           495.0
# 10                                           East St Kilda          1752.0
# 11                                                  Elwood          1738.0
#
#     Mar 2000 Median  Jun 2000 Count  Jun 2000 Median  Sep 2000 Count  \
# 2             260.0            1136              260          1177.0
# 3             200.0             731              200           732.0
# 4             260.0             814              260           800.0
# 5             260.0            1312              260          1306.0
# 6             320.0            2269              320          2362.0
# 7             230.0             654              230           700.0
# 8               NaN              10              340             NaN
# 9             265.0             490              268           516.0
# 10            180.0            1726              180          1704.0
# 11            200.0            1668              200          1663.0
#
#     Sep 2000 Median  Dec 2000 Count  Dec 2000 Median  ...  Jun 2020 Count  \
# 2             270.0          1176.0            275.0  ...             826
# 3             205.0           732.0            210.0  ...             782
# 4             265.0           735.0            270.0  ...             536
# 5             260.0          1322.0            260.0  ...            5025
# 6             320.0          2361.0            320.0  ...           11039
# 7             240.0           709.0            240.0  ...            1993
# 8               NaN             NaN              NaN  ...            2229
# 9             280.0           506.0            273.0  ...             629
# 10            180.0          1633.0            185.0  ...            1615
# 11            200.0          1696.0            210.0  ...            1557
#
#     Jun 2020 Median  Sep 2020 Count  Sep 2020 Median  Dec 2020 Count  \
# 2               585             802              560             848
# 3               500             709              500             729
# 4               590             520              590             547
# 5               400            4633              400            4764
# 6               495           11325              460           13473
# 7               490            1990              480            2089
# 8               550            2475              500            3009
# 9               550             562              515             549
# 10              425            1597              420            1616
# 11              450            1533              450            1592
#
#     Dec 2020 Median  Mar 2021 Count  Mar 2021 Median  Jun 2021 Count  \
# 2               550             898              500             932
# 3               495             792              450             813
# 4               590             579              580             598
# 5               395            4170              350            4763
# 6               420           15630              380           17553
# 7               460            2329              450            2475
# 8               460            3515              420            3821
# 9               495             574              450             599
# 10              410            1685              395            1708
# 11              440            1673              425            1669
#
#     Jun 2021 Median
# 2               500
# 3               440
# 4               580
# 5               340
# 6               370
# 7               430
# 8               400
# 9               450
# 10              385
# 11              425
#
# [10 rows x 174 columns]

# %%
#Check the rows and columns of new dataframe
df_all_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 2 to 160
# Columns: 174 entries, Region to Jun 2021 Median
# dtypes: float64(14), int64(158), object(2)
# memory usage: 216.3+ KB

# %%
#Check the Null values in each column of the new dataframe
df_all_new.isnull().sum()
# Out:
# Region             0
# Suburb             0
# Mar 2000 Count     1
# Mar 2000 Median    1
# Jun 2000 Count     0
#                   ..
# Dec 2020 Median    0
# Mar 2021 Count     0
# Mar 2021 Median    0
# Jun 2021 Count     0
# Jun 2021 Median    0
# Length: 174, dtype: int64

# %%
#Total number of Null values in the new dataframe
df_all_new.isnull().sum().sum()
# Out:
# 14

# %%
#Statistical information of the new dataframe
df_all_new.describe()
# Out:
#        Mar 2000 Count  Mar 2000 Median  Jun 2000 Count  Jun 2000 Median  \
# count      158.000000       158.000000      159.000000       159.000000
# mean      1692.170886       176.955696     1685.710692       179.886792
# std       3136.947809        46.061624     3145.900657        48.436175
# min         60.000000        95.000000       10.000000        90.000000
# 25%        610.000000       140.000000      623.500000       145.000000
# 50%        850.500000       170.000000      840.000000       170.000000
# 75%       1291.250000       200.000000     1274.000000       200.000000
# max      25935.000000       335.000000    26236.000000       350.000000
#
#        Sep 2000 Count  Sep 2000 Median  Dec 2000 Count  Dec 2000 Median  \
# count      158.000000       158.000000      158.000000       158.000000
# mean      1723.411392       181.120253     1716.379747       183.550633
# std       3203.336434        47.276576     3197.647608        47.549980
# min         80.000000        90.000000       85.000000        90.000000
# 25%        637.750000       145.000000      647.000000       150.000000
# 50%        859.500000       170.000000      849.500000       175.000000
# 75%       1282.250000       208.750000     1282.750000       210.000000
# max      26763.000000       350.000000    26844.000000       340.000000
#
#        Mar 2001 Count  Mar 2001 Median  ...  Jun 2020 Count  Jun 2020 Median  \
# count      158.000000       158.000000  ...      159.000000       159.000000
# mean      1710.107595       186.075949  ...     2780.981132       416.880503
# std       3201.848633        48.581083  ...     5714.875347        82.890989
# min         84.000000        90.000000  ...       57.000000       230.000000
# 25%        643.000000       150.000000  ...      775.000000       360.000000
# 50%        865.500000       180.000000  ...     1316.000000       410.000000
# 75%       1274.250000       210.000000  ...     2145.000000       464.000000
# max      27104.000000       350.000000  ...    52027.000000       750.000000
#
#        Sep 2020 Count  Sep 2020 Median  Dec 2020 Count  Dec 2020 Median  \
# count      159.000000       159.000000      159.000000       159.000000
# mean      2680.654088       415.559748     2726.389937       412.811321
# std       5571.286310        79.600871     5883.296769        75.134998
# min         54.000000       230.000000       51.000000       230.000000
# 25%        755.000000       360.000000      772.500000       362.500000
# 50%       1298.000000       410.000000     1284.000000       410.000000
# 75%       2003.000000       460.000000     1966.500000       450.000000
# max      51643.000000       733.000000    56711.000000       718.000000
#
#        Mar 2021 Count  Mar 2021 Median  Jun 2021 Count  Jun 2021 Median
# count      159.000000       159.000000      159.000000       159.000000
# mean      2768.666667       408.006289     2862.779874       407.937107
# std       6189.112502        70.370493     6573.109484        67.774261
# min         50.000000       240.000000       51.000000       250.000000
# 25%        756.000000       360.000000      746.500000       362.500000
# 50%       1286.000000       400.000000     1319.000000       400.000000
# 75%       1969.000000       450.000000     2046.500000       440.000000
# max      61353.000000       695.000000    66095.000000       700.000000
#
# [8 rows x 172 columns]

# %%
#Number of unique values in each column of the new dataframe
df_all_new.nunique(axis=0)
# Out:
# Region              14
# Suburb             147
# Mar 2000 Count     150
# Mar 2000 Median     43
# Jun 2000 Count     150
#                   ...
# Dec 2020 Median     49
# Mar 2021 Count     156
# Mar 2021 Median     45
# Jun 2021 Count     152
# Jun 2021 Median     46
# Length: 174, dtype: int64

# %% [markdown]
# ### Visualizing Data

# %% [markdown]
# ### Bar Chart

# %%
#Extract the Rent values of June 2021 of all Region 
Rents_Suburbs_June2021 = df_all_new[df_all_new['Suburb'] != 'Group Total']['Jun 2021 Median'].reset_index(drop=True)

# %%
#No of bins
bins = 8
#Define the Levels
levels = ['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5',
          'Level 6', 'Level 7', 'Level 8']

# %%
#Replace the numerical values into categorical value as levels
Values_cat2021 = pd.cut(Rents_Suburbs_June2021, bins, labels = levels, include_lowest = True)

# %%
#Get all the Suburbs
Suburbs = [suburb for suburb in df_all_new['Suburb'] if suburb != 'Group Total']

# %%
#Create the dataframe with all Suburbs and their corresponding Level of Rent in June 2021
data1 = {'Suburb' : Suburbs, 'Rent Levels of June 2021' : Values_cat2021}
df1 = pd.DataFrame(data1)

# %%
#Display the counts of Rent Levels in all Suburbs in June 2021
fig1 = px.histogram(df1, x="Rent Levels of June 2021")
fig1.show()
# Out:
# <div>                            <div id="d401c0da-516f-43e8-bf8e-e1f37b30beb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d401c0da-516f-43e8-bf8e-e1f37b30beb0")) {                    Plotly.newPlot(                        "d401c0da-516f-43e8-bf8e-e1f37b30beb0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Rent Levels of June 2021=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["Level 5","Level 4","Level 6","Level 2","Level 3","Level 4","Level 3","Level 4","Level 3","Level 4","Level 6","Level 5","Level 3","Level 3","Level 7","Level 4","Level 4","Level 4","Level 3","Level 3","Level 3","Level 5","Level 5","Level 4","Level 3","Level 5","Level 4","Level 4","Level 5","Level 4","Level 3","Level 5","Level 3","Level 5","Level 3","Level 5","Level 5","Level 4","Level 4","Level 4","Level 5","Level 8","Level 8","Level 3","Level 3","Level 4","Level 4","Level 7","Level 4","Level 3","Level 4","Level 3","Level 3","Level 2","Level 3","Level 2","Level 5","Level 2","Level 2","Level 3","Level 2","Level 3","Level 5","Level 5","Level 3","Level 4","Level 4","Level 3","Level 3","Level 3","Level 3","Level 4","Level 3","Level 3","Level 3","Level 3","Level 2","Level 3","Level 4","Level 3","Level 4","Level 4","Level 3","Level 5","Level 3","Level 3","Level 2","Level 3","Level 3","Level 3","Level 3","Level 4","Level 4","Level 3","Level 4","Level 4","Level 3","Level 3","Level 3","Level 2","Level 2","Level 3","Level 2","Level 3","Level 3","Level 4","Level 3","Level 4","Level 6","Level 3","Level 3","Level 1","Level 3","Level 3","Level 3","Level 3","Level 3","Level 2","Level 2","Level 2","Level 2","Level 2","Level 2","Level 2","Level 2","Level 2","Level 2","Level 3","Level 2","Level 1","Level 1","Level 2","Level 1","Level 1","Level 5","Level 2","Level 2","Level 1","Level 2","Level 1","Level 6","Level 2","Level 2","Level 3","Level 2","Level 2"],"xaxis":"x","yaxis":"y"}],                        {"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"] ...

# %% [markdown]
# ### Scatter Plot

# %%
#Extract all the Regions
Regions = df_all_new['Region'].replace('', np.nan).dropna()
Regions = Regions.reset_index(drop = True)

# %%
#Read other sheets in the excel file
df_1bd_flat =  pd.read_excel(xl_file, '1 bedroom flat')
df_2bd_flat =  pd.read_excel(xl_file, '2 bedroom flat')
df_3bd_flat =  pd.read_excel(xl_file, '3 bedroom flat')
df_2bd_house =  pd.read_excel(xl_file, '2 bedroom house')
df_3bd_house = pd.read_excel(xl_file, '3 bedroom house')
df_4bd_house =  pd.read_excel(xl_file, '4 bedroom house')

# %%
df_1bd_flat.head()
# Out:
#     1 bedroom flat                             Unnamed: 1  \
# 0              NaN                                    NaN
# 1           Region                                 Suburb
# 2  Inner Melbourne  Albert Park-Middle Park-West St Kilda
# 3              NaN                               Armadale
# 4              NaN                          Carlton North
#
#   Lease commenced in year ending  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                        Mar 2000        NaN   Jun 2000        NaN   Sep 2000
# 1                           Count     Median      Count     Median      Count
# 2                             352        165        346        165        376
# 3                             210        150        210        150        211
# 4                              86        150         77        155         74
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 164 Unnamed: 165  \
# 0        NaN   Dec 2000        NaN  ...     Jun 2020          NaN
# 1     Median      Count     Median  ...        Count       Median
# 2        170        367        175  ...          228          355
# 3        155        211        160  ...          208          368
# 4        150         65        150  ...           67          360
#
#   Unnamed: 166 Unnamed: 167 Unnamed: 168 Unnamed: 169 Unnamed: 170  \
# 0     Sep 2020          NaN     Dec 2020          NaN     Mar 2021
# 1        Count       Median        Count       Median        Count
# 2          231          350          243          350          271
# 3          170          350          184          350          208
# 4           72          350           64          350           72
#
#   Unnamed: 171 Unnamed: 172 Unnamed: 173
# 0          NaN     Jun 2021          NaN
# 1       Median        Count       Median
# 2          340          281          330
# 3          350          227          350
# 4          330           79          320
#
# [5 rows x 174 columns]

# %%
#Remove the first two rows and Assign the created list as headers
df_1bd_flat_new = df_1bd_flat[2:]
df_1bd_flat_new.columns = headers

df_2bd_flat_new = df_2bd_flat[2:]
df_2bd_flat_new.columns = headers

df_3bd_flat_new = df_3bd_flat[2:]
df_3bd_flat_new.columns = headers

df_2bd_house_new = df_2bd_house[2:]
df_2bd_house_new.columns = headers

df_3bd_house_new = df_3bd_house[2:]
df_3bd_house_new.columns = headers

df_4bd_house_new = df_4bd_house[2:]
df_4bd_house_new.columns = headers

# %%
df_1bd_flat_new
# Out:
#               Region                                 Suburb Mar 2000 Count  \
# 2    Inner Melbourne  Albert Park-Middle Park-West St Kilda            352
# 3                NaN                               Armadale            210
# 4                NaN                          Carlton North             86
# 5                NaN                      Carlton-Parkville            297
# 6                NaN                        CBD-St Kilda Rd            735
# ..               ...                                    ...            ...
# 156              NaN                            Wanagaratta             51
# 157              NaN                               Warragul             13
# 158              NaN                            Warrnambool            113
# 159              NaN                                Wodonga             76
# 160              NaN                            Group Total           1132
#
#     Mar 2000 Median Jun 2000 Count Jun 2000 Median Sep 2000 Count  \
# 2               165            346             165            376
# 3               150            210             150            211
# 4               150             77             155             74
# 5               170            297             170            310
# 6               250            844             250            912
# ..              ...            ...             ...            ...
# 156              85             45              85             43
# 157              80             11              75             12
# 158              75            103              75            107
# 159              85             72              85             77
# 160              80           1121              80           1143
#
#     Sep 2000 Median Dec 2000 Count Dec 2000 Median  ... Jun 2020 Count  \
# 2               170            367             175  ...            228
# 3               155            211             160  ...            208
# 4               150             65             150  ...             67
# 5               175            343             180  ...           3239
# 6               250            931             250  ...           5708
# ..              ...            ...             ...  ...            ...
# 156              85             46              85  ...             67
# 157              90             10              90  ...              -
# 158              75            103              80  ...             65
# 159              85             83              85  ...             57
# 160              80           1137              80  ...            977
#
#     Jun 2020 Median Sep 2020 Count Sep 2020 Median Dec 2020 Count  \
# 2               355            231             350            243
# 3               368            170             350            184
# 4               360             72             350             64
# 5               356           2919             350           2829
# 6               425           5624             400           6437
# ..              ...            ...             ...            ...
# 156             195             61             190             56
# 157               -              -               -              -
# 158             220             63             220             63
# 159             185             56             185             56
# 160             185            913             190            847
#
#     Dec 2020 Median Mar 2021 Count Mar 2021 Median Jun 2021 Count  \
# 2               350            271             340            281
# 3               350            208             350            227
# 4               350             72             330             79
# 5               340           2152             300           2441
# 6               360           7073             330           7656
# ..              ...            ...             ...            ...
# 156             195             53             195             51
# 157               -              -               -              -
# 158             230             57             250             54
# 159             185             60             200             55
# 160             195            828             200            815
#
#     Jun 2021 Median
# 2               330
# 3               350
# 4               320
# 5               295
# 6               320
# ..              ...
# 156             195
# 157               -
# 158             245
# 159             200
# 160             200
#
# [159 rows x 174 columns]

# %%
#Extract the 'Group Total' (Total of a Region) of Each Region from all type of houses
Rents_1bd_flat = df_1bd_flat_new[df_1bd_flat_new['Suburb']== 'Group Total']
Rents_1bd_flat = Rents_1bd_flat.reset_index(drop=True)
Rents_1bd_flat['Region'] = Regions

Rents_2bd_flat = df_2bd_flat_new[df_2bd_flat_new['Suburb']== 'Group Total']
Rents_2bd_flat = Rents_2bd_flat.reset_index(drop=True)
Rents_2bd_flat['Region'] = Regions

Rents_3bd_flat = df_3bd_flat_new[df_3bd_flat_new['Suburb']== 'Group Total']
Rents_3bd_flat = Rents_3bd_flat.reset_index(drop=True)
Rents_3bd_flat['Region'] = Regions

Rents_2bd_house = df_2bd_house_new[df_2bd_house_new['Suburb']== 'Group Total']
Rents_2bd_house = Rents_2bd_house.reset_index(drop=True)
Rents_2bd_house['Region'] = Regions

Rents_3bd_house = df_3bd_house_new[df_3bd_house_new['Suburb']== 'Group Total']
Rents_3bd_house = Rents_3bd_house.reset_index(drop=True)
Rents_2bd_house['Region'] = Regions

Rents_4bd_house = df_4bd_house_new[df_4bd_house_new['Suburb']== 'Group Total']
Rents_4bd_house = Rents_4bd_house.reset_index(drop=True)
Rents_2bd_house['Region']  = Regions

# %%
Rents_1bd_flat
# Out:
#                      Region       Suburb Mar 2000 Count Mar 2000 Median  \
# 0           Inner Melbourne  Group Total           7685             160
# 1   Inner Eastern Melbourne  Group Total           1239             140
# 2        Southern Melbourne  Group Total           1965             125
# 3   Outer Western Melbourne  Group Total            995              95
# 4   North Western Melbourne  Group Total           1514             115
# 5   North Eastern Melbourne  Group Total           1326             110
# 6   Outer Eastern Melbourne  Group Total            297             115
# 7   South Eastern Melbourne  Group Total            441             100
# 8      Mornington Peninsula  Group Total            271              95
# 9                   Geelong  Group Total            839              80
# 10                 Ballarat  Group Total            388              80
# 11                  Bendigo  Group Total            184              85
# 12   Other Regional Centres  Group Total           1132              80
#
#    Jun 2000 Count Jun 2000 Median Sep 2000 Count Sep 2000 Median  \
# 0            7916             165           8175             170
# 1            1271             140           1306             145
# 2            1994             130           2041             130
# 3             972              95            997              95
# 4            1541             120           1540             120
# 5            1301             115           1314             115
# 6             304             115            300             115
# 7             451             100            464             100
# 8             280             100            288             100
# 9             812              85            790              85
# 10            382              80            385              80
# 11            175              85            180              85
# 12           1121              80           1143              80
#
#    Dec 2000 Count Dec 2000 Median  ... Jun 2020 Count Jun 2020 Median  \
# 0            8311             170  ...          22666             400
# 1            1268             145  ...           3841             340
# 2            2073             130  ...           2951             325
# 3             972             100  ...           1663             295
# 4            1490             120  ...           2736             345
# 5            1291             117  ...           2031             325
# 6             298             115  ...            344             310
# 7             429             100  ...            785             265
# 8             278              96  ...            466             250
# 9             794              85  ...            541             250
# 10            400              80  ...            230             190
# 11            188              90  ...            133             200
# 12           1137              80  ...            977             185
#
#    Sep 2020 Count Sep 2020 Median Dec 2020 Count Dec 2020 Median  \
# 0           21964             380          23559             360
# 1            3755             340           3827             330
# 2            2851             320           2851             320
# 3            1610             300           1538             290
# 4            2594             345           2709             340
# 5            1873             320           1938             320
# 6             314             315            309             320
# 7             679             260            682             260
# 8             444             250            415             250
# 9             540             250            540             255
# 10            221             194            217             193
# 11            116             197             97             210
# 12            913             190            847             195
#
#    Mar 2021 Count Mar 2021 Median Jun 2021 Count Jun 2021 Median
# 0           24040             340          25883             330
# 1            3519             330           3780             320
# 2            2715             315           2950             310
# 3            1526             290           1695             290
# 4            2701             330           2798             320
# 5            1902             310           2046             310
# 6             277             320            275             320
# 7             658             260            663             260
# 8             436             250            422             255
# 9             550             260            525             255
# 10            189             195            191             200
# 11             99             220             95             220
# 12            828             200            815             200
#
# [13 rows x 174 columns]

# %%
#Extract the Rent of June 2021 of Each Region from all type of houses 
Jun2021Median = []
for i in range (0, len(Regions)):
    Jun2021MedianReg = []
    Jun2021MedianReg.append(Rents_1bd_flat['Jun 2021 Median'][i])
    Jun2021MedianReg.append(Rents_2bd_flat['Jun 2021 Median'][i])
    Jun2021MedianReg.append(Rents_3bd_flat['Jun 2021 Median'][i])
    Jun2021MedianReg.append(Rents_2bd_house['Jun 2021 Median'][i])
    Jun2021MedianReg.append(Rents_3bd_house['Jun 2021 Median'][i])
    Jun2021MedianReg.append(Rents_4bd_house['Jun 2021 Median'][i])
    Jun2021Median.append(Jun2021MedianReg)

# %%
#Create dataframe with the Rent of June 2021 of all regions for all type of house 
Jun2021Median = np.array(Jun2021Median)
Median_June2021 = Jun2021Median.reshape(-1)

Type = ['1 bedroom flat', '2 bedroom flat', '3 bedroom flat', 
         '2 bedroom house', '3 bedroom house', '4 bedroom house']
Types = 13*Type

Regions_new = []
for i in range (0, len(Regions)):
    for j in range (0, 6):
        Regions_new.append(Regions[i])
        
data2 = {'Type of House': Types, 'Regions' : Regions_new, 'Rent($) of June 2021' : Median_June2021}
df2 = pd.DataFrame(data2)

# %%
#Display the Rents of June 2021 of each type of houses for each region 
fig2 = px.scatter(df2, y='Rent($) of June 2021', x='Type of House', color="Regions", symbol="Regions")
fig2.show()
# Out:
# <div>                            <div id="ff0b637d-59b8-448d-8f5f-b62143c68a53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff0b637d-59b8-448d-8f5f-b62143c68a53")) {                    Plotly.newPlot(                        "ff0b637d-59b8-448d-8f5f-b62143c68a53",                        [{"hovertemplate":"Regions=Inner Melbourne<br>Type of House=%{x}<br>Rent($) of June 2021=%{y}<extra></extra>","legendgroup":"Inner Melbourne","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Inner Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":["1 bedroom flat","2 bedroom flat","3 bedroom flat","2 bedroom house","3 bedroom house","4 bedroom house"],"xaxis":"x","y":[330,425,650,580,750,950],"yaxis":"y"},{"hovertemplate":"Regions=Inner Eastern Melbourne<br>Type of House=%{x}<br>Rent($) of June 2021=%{y}<extra></extra>","legendgroup":"Inner Eastern Melbourne","marker":{"color":"#EF553B","symbol":"diamond"},"mode":"markers","name":"Inner Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":["1 bedroom flat","2 bedroom flat","3 bedroom flat","2 bedroom house","3 bedroom house","4 bedroom house"],"xaxis":"x","y":[320,400,500,425,475,600],"yaxis":"y"},{"hovertemplate":"Regions=Southern Melbourne<br>Type of House=%{x}<br>Rent($) of June 2021=%{y}<extra></extra>","legendgroup":"Southern Melbourne","marker":{"color":"#00cc96","symbol":"square"},"mode":"markers","name":"Southern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":["1 bedroom flat","2 bedroom flat","3 bedroom flat","2 bedroom house","3 bedroom house","4 bedroom house"],"xaxis":"x","y":[310,420,580,490,595,800],"yaxis":"y"},{"hovertemplate":"Regions=Outer Western Melbourne<br>Type of House=%{x}<br>Rent($) of June 2021=%{y}<extra></extra>","legendgroup":"Outer Western Melbourne","marker":{"color":"#ab63fa","symbol":"x"},"mode":"markers","name":"Outer Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":["1 bedroom flat","2 bedroom flat","3 bedroom flat","2 bedroom house","3 bedroom house","4 bedroom house"],"xaxis":"x","y":[290,350,370,380,360,400],"yaxis":"y"},{"hovertemplate":"Regions=North Western Melbourne<br>Type of House=%{x}<br>Rent($) of June 2021=%{y}<extra></extra>","legendgroup":"North Western Melbourne","marker":{"color":"#FFA15A","symbol":"cross"},"mode":"markers","name":"North Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":["1 bedroom flat","2 bedroom flat","3 bedroom flat","2 bedroom house","3 bedroom house","4 bedroom house"],"xaxis":"x","y":[320,380,450,430,400,440],"yaxis":"y"},{"hovertemplate":"Regions=North Eastern Melbourne<br>Type of House=%{x}<br>Rent($) of June 2021=%{y}<extra></extra>","legendgroup":"North Eastern Melbourne","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"North Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":["1 bedroom flat","2 bedroom flat","3 bedroom flat","2 bedroom house","3 bedroom house","4 bedroom house"],"xaxis":"x","y":[310,380,450,400,400,450],"yaxis":"y"},{"hovertemplate":"Regions=Outer Eastern Melbourne<br>Type of House=%{x}<br>Rent($) of June 2021=%{y}<extra></extra>","legendgroup":"Outer Eastern Melbourne","marker":{"color":"#FF6692","symbol":"diamond"},"mode":"markers","name":"Outer Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":["1 bedroom flat","2 bedroom flat","3 bedroom flat","2 bedroom house","3 bedroom house","4 bedroom house"],"xaxis":"x","y":[320,375,440,380,430,515],"yaxis":"y"},{"hovertemplate":"Regions=South Eastern Melbourne<br>Type of House=%{x}<br>Rent($) of June 2021=%{y}<extra></extra>","legendgroup":"South Eastern Melbourne","marker":{"color":"#B6E880","symbol":"square ...

# %% [markdown]
# ### Pie Chart

# %%
# As we can see comparatively larger variation in the rent of 3 bedroom house and 4 bedroom house in 
#Inner Melbourne and Southern Melbourne, let's see the number of 3 and 4 bedroom houses in those 
#regions with other regions
fig3 = go.Figure(data = [go.Pie(labels = Regions, values= Rents_3bd_house['Jun 2021 Count'], 
                                pull=[0.2, 0, 0.2])])
fig3.show()
# Out:
# <div>                            <div id="ee6caa01-61b1-4208-bd5a-1f29b605f5fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee6caa01-61b1-4208-bd5a-1f29b605f5fc")) {                    Plotly.newPlot(                        "ee6caa01-61b1-4208-bd5a-1f29b605f5fc",                        [{"labels":["Inner Melbourne","Inner Eastern Melbourne","Southern Melbourne","Outer Western Melbourne","North Western Melbourne","North Eastern Melbourne","Outer Eastern Melbourne","South Eastern Melbourne","Mornington Peninsula","Geelong","Ballarat","Bendigo","Other Regional Centres"],"pull":[0.2,0,0.2],"type":"pie","values":[2037,3894,2127,8678,4043,4152,2381,5130,2476,2311,1749,1110,4948]}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}] ...
#
# var gd = document.getElementBy

# %%
fig4 = go.Figure(data = [go.Pie(labels = Regions, values= Rents_4bd_house['Jun 2021 Count'], pull=[0.2, 0, 0.2])])
fig4.show()
# Out:
# <div>                            <div id="ec3fd8ec-2339-4a12-8db4-5790d78fa847" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec3fd8ec-2339-4a12-8db4-5790d78fa847")) {                    Plotly.newPlot(                        "ec3fd8ec-2339-4a12-8db4-5790d78fa847",                        [{"labels":["Inner Melbourne","Inner Eastern Melbourne","Southern Melbourne","Outer Western Melbourne","North Western Melbourne","North Eastern Melbourne","Outer Eastern Melbourne","South Eastern Melbourne","Mornington Peninsula","Geelong","Ballarat","Bendigo","Other Regional Centres"],"pull":[0.2,0,0.2],"type":"pie","values":[478,2795,1337,8478,2313,2167,1079,3825,983,876,1113,391,2156]}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"sc ...
#
# var gd = document.getElementById('

# %% [markdown]
# ### Line Chart

# %%
#Extract the Rents of June from 2000 to 2021 for all type of houses in all regions 
contains = ['Jun', 'Median']
Year_June = [year for year in Rents_1bd_flat.columns if all(strings in year for strings in contains)]

Rents_1bd_flat_June = Rents_1bd_flat[Year_June]
Rents_2bd_flat_June = Rents_2bd_flat[Year_June]
Rents_3bd_flat_June = Rents_3bd_flat[Year_June]
Rents_2bd_house_June = Rents_2bd_house[Year_June]
Rents_3bd_house_June = Rents_3bd_house[Year_June]
Rents_4bd_house_June = Rents_4bd_house[Year_June]

# %%
#Create a dataframe containes the Rent values of June from 2000 to 2021 for all type of houses
#in all regions
columns = list(Rents_1bd_flat_June)

Regions_new = []
Rents_June_1bdf = []
Rents_June_2bdf = []
Rents_June_3bdf = []
Rents_June_2bdh = []
Rents_June_3bdh = []
Rents_June_4bdh = []

for j in range (0, len(Rents_1bd_flat_June)):
    for col in columns:
        Rents_June_1bdf.append(Rents_1bd_flat_June[col][j])
        Rents_June_2bdf.append(Rents_2bd_flat_June[col][j])
        Rents_June_3bdf.append(Rents_3bd_flat_June[col][j])
        Rents_June_2bdh.append(Rents_2bd_house_June[col][j])
        Rents_June_3bdh.append(Rents_3bd_house_June[col][j])
        Rents_June_4bdh.append(Rents_4bd_house_June[col][j])
        Regions_new.append(Regions[j])

Years = [ i for i in range (2000, 2022)]
Years_new = len(Rents_1bd_flat_June)*Years

data5 = {'Region' : Regions_new, 'Years' : Years_new, 'Rent($) 1 bd flat' : Rents_June_1bdf, 
         'Rent($) 2 bd flat' : Rents_June_2bdf, 'Rent($) 3 bd flat' : Rents_June_3bdf ,
        'Rent($) 2 bd house' : Rents_June_2bdh, 'Rent($) 3 bd house' : Rents_June_3bdh,
        'Rent($) 4 bd house' : Rents_June_4bdh}

df5 = pd.DataFrame(data5)

# %%
#Display the Rents of June from 2000 to 2021 for 1 bedroom flat in all regions
fig5 = px.line(df5, x="Years", y='Rent($) 1 bd flat', color = 'Region')
fig5.show()
# Out:
# <div>                            <div id="23143347-c909-4caf-bbee-7f0919a80d7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23143347-c909-4caf-bbee-7f0919a80d7e")) {                    Plotly.newPlot(                        "23143347-c909-4caf-bbee-7f0919a80d7e",                        [{"hovertemplate":"Region=Inner Melbourne<br>Years=%{x}<br>Rent($) 1 bd flat=%{y}<extra></extra>","legendgroup":"Inner Melbourne","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[165,180,195,200,220,230,240,255,280,310,320,330,340,345,350,350,360,380,399,404,400,330],"yaxis":"y"},{"hovertemplate":"Region=Inner Eastern Melbourne<br>Years=%{x}<br>Rent($) 1 bd flat=%{y}<extra></extra>","legendgroup":"Inner Eastern Melbourne","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[140,150,155,160,169,180,190,195,215,240,250,260,265,279,270,280,300,310,320,330,340,320],"yaxis":"y"},{"hovertemplate":"Region=Southern Melbourne<br>Years=%{x}<br>Rent($) 1 bd flat=%{y}<extra></extra>","legendgroup":"Southern Melbourne","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Southern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[130,135,140,148,155,160,170,185,210,230,240,250,260,265,270,275,285,300,305,320,325,310],"yaxis":"y"},{"hovertemplate":"Region=Outer Western Melbourne<br>Years=%{x}<br>Rent($) 1 bd flat=%{y}<extra></extra>","legendgroup":"Outer Western Melbourne","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Outer Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[95,100,110,115,120,125,130,145,170,195,200,210,220,220,233,250,250,265,280,280,295,290],"yaxis":"y"},{"hovertemplate":"Region=North Western Melbourne<br>Years=%{x}<br>Rent($) 1 bd flat=%{y}<extra></extra>","legendgroup":"North Western Melbourne","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[120,123,130,140,140,150,150,170,190,220,240,250,260,260,275,280,295,300,320,350,345,320],"yaxis":"y"},{"hovertemplate":"Region=North Eastern Melbourne<br>Years=%{x}<br>Rent($) 1 bd flat=%{y}<extra></extra>","legendgroup":"North Eastern Melbourne","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[115,120,130,140,147,150,160,171,195,220,240,250,260,260,270,270,280,295,300,320,325,310],"yaxis":"y"},{"hovertemplate":"Region=Outer Eastern Melbourne<br>Years=%{x}<br>Rent($) 1 bd flat=%{y}<extra></extra>","legendgroup":"Outer Eastern Melbourne","line":{"color":"#FF6692","dash":"solid"},"marker":{ ...

# %%
#Display the Rents of June from 2000 to 2021 for 2 bedroom flat in all regions
fig6 = px.line(df5, x="Years", y='Rent($) 2 bd flat', color = 'Region')
fig6.show()
# Out:
# <div>                            <div id="700b2e39-4b6f-41f2-ad76-8302f02e7b84" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("700b2e39-4b6f-41f2-ad76-8302f02e7b84")) {                    Plotly.newPlot(                        "700b2e39-4b6f-41f2-ad76-8302f02e7b84",                        [{"hovertemplate":"Region=Inner Melbourne<br>Years=%{x}<br>Rent($) 2 bd flat=%{y}<extra></extra>","legendgroup":"Inner Melbourne","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[250,270,280,295,300,310,325,350,390,420,440,450,475,480,480,490,500,520,550,560,550,425],"yaxis":"y"},{"hovertemplate":"Region=Inner Eastern Melbourne<br>Years=%{x}<br>Rent($) 2 bd flat=%{y}<extra></extra>","legendgroup":"Inner Eastern Melbourne","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[185,195,200,210,220,225,235,255,290,320,335,350,360,360,370,380,390,400,420,430,440,400],"yaxis":"y"},{"hovertemplate":"Region=Southern Melbourne<br>Years=%{x}<br>Rent($) 2 bd flat=%{y}<extra></extra>","legendgroup":"Southern Melbourne","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Southern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[175,185,195,200,210,220,230,250,290,320,330,350,360,360,370,380,395,415,430,445,450,420],"yaxis":"y"},{"hovertemplate":"Region=Outer Western Melbourne<br>Years=%{x}<br>Rent($) 2 bd flat=%{y}<extra></extra>","legendgroup":"Outer Western Melbourne","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Outer Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[140,145,150,155,160,165,175,185,210,240,255,270,280,285,300,300,310,325,340,350,355,350],"yaxis":"y"},{"hovertemplate":"Region=North Western Melbourne<br>Years=%{x}<br>Rent($) 2 bd flat=%{y}<extra></extra>","legendgroup":"North Western Melbourne","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[150,160,170,180,180,190,200,220,250,285,300,320,330,330,340,345,350,370,380,400,400,380],"yaxis":"y"},{"hovertemplate":"Region=North Eastern Melbourne<br>Years=%{x}<br>Rent($) 2 bd flat=%{y}<extra></extra>","legendgroup":"North Eastern Melbourne","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[160,165,175,180,185,190,200,220,255,285,300,310,320,320,330,330,340,355,370,380,390,380],"yaxis":"y"},{"hovertemplate":"Region=Outer Eastern Melbourne<br>Years=%{x}<br>Rent($) 2 bd flat=%{y}<extra></extra>","legendgroup":"Outer Eastern Melbourne","line":{"color":"#FF6692","dash":"solid"},"marker": ...

# %%
#Display the Rents of June from 2000 to 2021 for 3 bedroom flat in all regions
fig7 = px.line(df5, x="Years", y='Rent($) 3 bd flat', color = 'Region')
fig7.show()
# Out:
# <div>                            <div id="402be81a-617d-4972-9b6f-748742ae4d13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("402be81a-617d-4972-9b6f-748742ae4d13")) {                    Plotly.newPlot(                        "402be81a-617d-4972-9b6f-748742ae4d13",                        [{"hovertemplate":"Region=Inner Melbourne<br>Years=%{x}<br>Rent($) 3 bd flat=%{y}<extra></extra>","legendgroup":"Inner Melbourne","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[370,390,400,410,420,430,455,500,570,600,630,650,675,680,690,700,720,750,770,750,795,650],"yaxis":"y"},{"hovertemplate":"Region=Inner Eastern Melbourne<br>Years=%{x}<br>Rent($) 3 bd flat=%{y}<extra></extra>","legendgroup":"Inner Eastern Melbourne","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[242,250,260,270,275,280,300,320,360,390,400,420,430,440,450,460,480,500,520,520,530,500],"yaxis":"y"},{"hovertemplate":"Region=Southern Melbourne<br>Years=%{x}<br>Rent($) 3 bd flat=%{y}<extra></extra>","legendgroup":"Southern Melbourne","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Southern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[255,270,275,285,290,300,310,340,380,400,430,450,475,470,485,500,520,550,560,580,580,580],"yaxis":"y"},{"hovertemplate":"Region=Outer Western Melbourne<br>Years=%{x}<br>Rent($) 3 bd flat=%{y}<extra></extra>","legendgroup":"Outer Western Melbourne","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Outer Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[180,185,195,200,195,200,210,220,240,270,280,295,300,300,315,320,340,350,360,370,370,370],"yaxis":"y"},{"hovertemplate":"Region=North Western Melbourne<br>Years=%{x}<br>Rent($) 3 bd flat=%{y}<extra></extra>","legendgroup":"North Western Melbourne","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[200,220,220,230,230,240,240,260,300,340,350,360,360,360,370,375,395,410,420,450,450,450],"yaxis":"y"},{"hovertemplate":"Region=North Eastern Melbourne<br>Years=%{x}<br>Rent($) 3 bd flat=%{y}<extra></extra>","legendgroup":"North Eastern Melbourne","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[200,210,220,230,230,230,250,270,300,330,340,360,360,360,365,380,395,400,430,440,450,450],"yaxis":"y"},{"hovertemplate":"Region=Outer Eastern Melbourne<br>Years=%{x}<br>Rent($) 3 bd flat=%{y}<extra></extra>","legendgroup":"Outer Eastern Melbourne","line":{"color":"#FF6692","dash":"solid"},"marker": ...

# %%
#Display the Rents of June from 2000 to 2021 for 2 bedroom house in all regions
fig8 = px.line(df5, x="Years", y='Rent($) 2 bd house', color = 'Region')
fig8.show()
# Out:
# <div>                            <div id="d49a4d32-2a6c-4fbe-a383-f10a11182c46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d49a4d32-2a6c-4fbe-a383-f10a11182c46")) {                    Plotly.newPlot(                        "d49a4d32-2a6c-4fbe-a383-f10a11182c46",                        [{"hovertemplate":"Region=Inner Melbourne<br>Years=%{x}<br>Rent($) 2 bd house=%{y}<extra></extra>","legendgroup":"Inner Melbourne","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[260,270,290,295,300,310,320,360,400,430,450,480,500,520,530,550,550,560,595,600,610,580],"yaxis":"y"},{"hovertemplate":"Region=Inner Eastern Melbourne<br>Years=%{x}<br>Rent($) 2 bd house=%{y}<extra></extra>","legendgroup":"Inner Eastern Melbourne","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[210,220,225,230,235,245,255,280,310,340,350,368,370,375,395,395,400,410,420,430,440,425],"yaxis":"y"},{"hovertemplate":"Region=Southern Melbourne<br>Years=%{x}<br>Rent($) 2 bd house=%{y}<extra></extra>","legendgroup":"Southern Melbourne","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Southern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[220,230,240,250,250,255,280,300,330,360,375,395,400,410,428,430,440,450,470,480,480,490],"yaxis":"y"},{"hovertemplate":"Region=Outer Western Melbourne<br>Years=%{x}<br>Rent($) 2 bd house=%{y}<extra></extra>","legendgroup":"Outer Western Melbourne","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Outer Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[170,175,185,190,195,200,200,230,265,290,295,310,310,320,330,350,350,370,380,380,390,380],"yaxis":"y"},{"hovertemplate":"Region=North Western Melbourne<br>Years=%{x}<br>Rent($) 2 bd house=%{y}<extra></extra>","legendgroup":"North Western Melbourne","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[190,200,210,210,220,220,230,250,300,323,340,350,360,360,380,390,395,410,440,430,433,430],"yaxis":"y"},{"hovertemplate":"Region=North Eastern Melbourne<br>Years=%{x}<br>Rent($) 2 bd house=%{y}<extra></extra>","legendgroup":"North Eastern Melbourne","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[180,190,200,200,210,215,230,240,270,300,320,335,340,346,350,350,350,360,390,400,400,400],"yaxis":"y"},{"hovertemplate":"Region=Outer Eastern Melbourne<br>Years=%{x}<br>Rent($) 2 bd house=%{y}<extra></extra>","legendgroup":"Outer Eastern Melbourne","line":{"color":"#FF6692","dash":"solid"},"m ...

# %%
#Display the Rents of June from 2000 to 2021 for 3 bedroom house in all regions
fig9 = px.line(df5, x="Years", y='Rent($) 3 bd house', color = 'Region')
fig9.show()
# Out:
# <div>                            <div id="f57d694b-224b-459a-9c08-b3e7bbf61749" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f57d694b-224b-459a-9c08-b3e7bbf61749")) {                    Plotly.newPlot(                        "f57d694b-224b-459a-9c08-b3e7bbf61749",                        [{"hovertemplate":"Region=Inner Melbourne<br>Years=%{x}<br>Rent($) 3 bd house=%{y}<extra></extra>","legendgroup":"Inner Melbourne","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[320,335,350,360,375,380,400,450,515,550,600,630,668,680,695,700,720,750,780,795,795,750],"yaxis":"y"},{"hovertemplate":"Region=Inner Eastern Melbourne<br>Years=%{x}<br>Rent($) 3 bd house=%{y}<extra></extra>","legendgroup":"Inner Eastern Melbourne","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[220,230,240,250,250,260,271,300,345,370,380,395,400,400,420,430,450,450,470,480,480,475],"yaxis":"y"},{"hovertemplate":"Region=Southern Melbourne<br>Years=%{x}<br>Rent($) 3 bd house=%{y}<extra></extra>","legendgroup":"Southern Melbourne","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Southern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[250,260,270,280,290,300,320,350,395,420,450,460,480,495,500,500,530,550,550,580,580,595],"yaxis":"y"},{"hovertemplate":"Region=Outer Western Melbourne<br>Years=%{x}<br>Rent($) 3 bd house=%{y}<extra></extra>","legendgroup":"Outer Western Melbourne","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Outer Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[170,180,185,190,195,200,210,220,250,280,290,300,300,300,315,325,340,350,360,370,370,360],"yaxis":"y"},{"hovertemplate":"Region=North Western Melbourne<br>Years=%{x}<br>Rent($) 3 bd house=%{y}<extra></extra>","legendgroup":"North Western Melbourne","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[185,195,200,210,210,220,220,240,280,310,325,335,340,340,350,350,360,380,395,400,400,400],"yaxis":"y"},{"hovertemplate":"Region=North Eastern Melbourne<br>Years=%{x}<br>Rent($) 3 bd house=%{y}<extra></extra>","legendgroup":"North Eastern Melbourne","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[185,195,210,210,220,230,235,250,290,320,335,350,350,340,350,350,365,380,395,400,400,400],"yaxis":"y"},{"hovertemplate":"Region=Outer Eastern Melbourne<br>Years=%{x}<br>Rent($) 3 bd house=%{y}<extra></extra>","legendgroup":"Outer Eastern Melbourne","line":{"color":"#FF6692","dash":"solid"},"m ...

# %%
#Display the Rents of June from 2000 to 2021 for 4 bedroom house in all regions
fig10 = px.line(df5, x="Years", y='Rent($) 4 bd house', color = 'Region')
fig10.show()
# Out:
# <div>                            <div id="2fcc485a-33b8-44bb-8f3b-c20b5f2597ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fcc485a-33b8-44bb-8f3b-c20b5f2597ee")) {                    Plotly.newPlot(                        "2fcc485a-33b8-44bb-8f3b-c20b5f2597ee",                        [{"hovertemplate":"Region=Inner Melbourne<br>Years=%{x}<br>Rent($) 4 bd house=%{y}<extra></extra>","legendgroup":"Inner Melbourne","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[400,435,430,450,465,480,530,600,650,700,760,776,850,875,895,895,950,950,1000,1000,1000,950],"yaxis":"y"},{"hovertemplate":"Region=Inner Eastern Melbourne<br>Years=%{x}<br>Rent($) 4 bd house=%{y}<extra></extra>","legendgroup":"Inner Eastern Melbourne","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Inner Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[290,300,315,320,330,345,350,390,423,450,470,495,500,500,530,550,560,580,600,615,620,600],"yaxis":"y"},{"hovertemplate":"Region=Southern Melbourne<br>Years=%{x}<br>Rent($) 4 bd house=%{y}<extra></extra>","legendgroup":"Southern Melbourne","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Southern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[350,400,400,420,420,440,460,485,570,600,630,625,685,700,700,740,750,780,795,800,800,800],"yaxis":"y"},{"hovertemplate":"Region=Outer Western Melbourne<br>Years=%{x}<br>Rent($) 4 bd house=%{y}<extra></extra>","legendgroup":"Outer Western Melbourne","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Outer Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[200,215,230,230,240,250,255,270,310,320,320,330,330,340,350,360,380,390,400,410,400,400],"yaxis":"y"},{"hovertemplate":"Region=North Western Melbourne<br>Years=%{x}<br>Rent($) 4 bd house=%{y}<extra></extra>","legendgroup":"North Western Melbourne","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Western Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[230,235,250,250,250,258,275,300,340,360,370,373,370,375,380,390,400,420,430,440,430,440],"yaxis":"y"},{"hovertemplate":"Region=North Eastern Melbourne<br>Years=%{x}<br>Rent($) 4 bd house=%{y}<extra></extra>","legendgroup":"North Eastern Melbourne","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North Eastern Melbourne","orientation":"v","showlegend":true,"type":"scatter","x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[245,250,260,270,280,280,300,330,360,380,390,395,380,375,380,390,400,400,430,430,430,450],"yaxis":"y"},{"hovertemplate":"Region=Outer Eastern Melbourne<br>Years=%{x}<br>Rent($) 4 bd house=%{y}<extra></extra>","legendgroup":"Outer Eastern Melbourne","line":{"color":"#FF6692","dash":"solid"} ...

# %% [markdown]
# ### Bar Chart

# %%
#As we can see the significant drop in the Rent for 1, 2 and 3 bedroom flat in Inner Melbourne region,
#let's see the number of houses in that period in Inner Melbourne region

#Create a new column list from 2019 to 2021
Columns_2019_2021 = headers [len(headers)-20:len(headers)]
Count_June_2019_2021 = []

#Get only the columns that have Jun and Count
for i in Columns_2019_2021:
    if 'Count' in i:
        if 'Jun' in i:
            Count_June_2019_2021.append(i)

# %%
#Create dataframes containing the number of houses in June from 2019 to 2021 for 1, 2 and 3 
#bedroom flats in Inner Melbourne region
Counts_1bd_flat_IM = Rents_1bd_flat[Count_June_2019_2021].iloc[0]
Counts_2bd_flat_IM = Rents_2bd_flat[Count_June_2019_2021].iloc[0]
Counts_3bd_flat_IM = Rents_3bd_flat[Count_June_2019_2021].iloc[0]

Counts_IM_2019_2021 = [*Counts_1bd_flat_IM, *Counts_2bd_flat_IM, *Counts_3bd_flat_IM]
Types_IM = ['1 bedroom flat', '2 bedroom flat','3 bedroom flat']

Types_IM_June = []
for i in range (0, len(Types_IM)):
    for j in range (0, len(Count_June_2019_2021)):
        Types_IM_June.append(Types_IM[i])

data6 = { 'Month - Year' : 3*Count_June_2019_2021, 'Type of House' : Types_IM_June, 
        '# of Houses' : Counts_IM_2019_2021}
df6 = pd.DataFrame(data6)

# %%
#Display the changes in number of houses from 2019 to 2021 for 1, 2 and 3 bedroom flats in
#in Inner Melbourne region
fig11 = px.bar(df6, x="Type of House", y="# of Houses",
             color='Month - Year', barmode='group')
fig11.show()
# Out:
# <div>                            <div id="ddfafa3c-7922-440c-9fa7-ebd212d642eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddfafa3c-7922-440c-9fa7-ebd212d642eb")) {                    Plotly.newPlot(                        "ddfafa3c-7922-440c-9fa7-ebd212d642eb",                        [{"alignmentgroup":"True","hovertemplate":"Month - Year=Jun 2019 Count<br>Type of House=%{x}<br># of Houses=%{y}<extra></extra>","legendgroup":"Jun 2019 Count","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Jun 2019 Count","offsetgroup":"Jun 2019 Count","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["1 bedroom flat","2 bedroom flat","3 bedroom flat"],"xaxis":"x","y":[20471,20049,2617],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Month - Year=Jun 2020 Count<br>Type of House=%{x}<br># of Houses=%{y}<extra></extra>","legendgroup":"Jun 2020 Count","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Jun 2020 Count","offsetgroup":"Jun 2020 Count","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["1 bedroom flat","2 bedroom flat","3 bedroom flat"],"xaxis":"x","y":[22666,20540,2423],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Month - Year=Jun 2021 Count<br>Type of House=%{x}<br># of Houses=%{y}<extra></extra>","legendgroup":"Jun 2021 Count","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Jun 2021 Count","offsetgroup":"Jun 2021 Count","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["1 bedroom flat","2 bedroom flat","3 bedroom flat"],"xaxis":"x","y":[25883,29719,3495],"yaxis":"y"}],                        {"barmode":"group","legend":{"title":{"text":"Month - Year"},"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d": ...

# %% [markdown]
# ### Bubble Map

# %%
#Get the australian localities with latitude and longitude
#Got the file from here : https://www.matthewproctor.com/australian_postcodes
aus_df = pd.read_csv('C:/Users/PCZ/Downloads/australian_postcodes.csv')
aus_lat_long = aus_df[['locality', 'long', 'lat']]
aus_lat_long = aus_lat_long.rename({'locality': 'Suburb'}, axis=1)
aus_lat_long
# Out:
#                                Suburb        long        lat
# 0                                 ANU  149.119000 -35.277700
# 1      Australian National University  149.118900 -35.277700
# 2                              DARWIN  130.836680 -12.458684
# 3                              DARWIN  130.836680 -12.458684
# 4                               PARAP  130.873315 -12.428017
# ...                               ...         ...        ...
# 18438                        BRISBANE  152.823141 -27.603479
# 18439                        BRISBANE  152.823141 -27.603479
# 18440                    NORTHGATE MC  153.074982 -27.397055
# 18441                   GOLD COAST MC  153.412197 -28.008783
# 18442                      NORTH POLE  144.956776 -37.817403
#
# [18443 rows x 3 columns]

# %%
#Get all the suburbs and their corresonding count and rents of June 2021
RentCount_all_June2021 = df_all_new[df_1bd_flat_new['Suburb'] != 'Group Total'][['Suburb','Jun 2021 Count','Jun 2021 Median']]
RentCount_all_June2021 = RentCount_all_June2021.reset_index(drop=True)

RentCount_all_June2021['Suburb'] = RentCount_all_June2021.Suburb.str.split('-')

Suburb, Jun_2021_Count, Jun_2021_Median = [], [], []

for i in range (0, len(RentCount_all_June2021)):
    for j in range(0, len(RentCount_all_June2021['Suburb'].iloc[i])):
        Suburb.append(RentCount_all_June2021['Suburb'].iloc[i][j])
        Jun_2021_Count.append(RentCount_all_June2021['Jun 2021 Count'].iloc[i])
        Jun_2021_Median.append(RentCount_all_June2021['Jun 2021 Median'].iloc[i])
    
RentCount_all_suburb = pd.DataFrame({'Suburb' : Suburb, 'Jun 2021 Count': Jun_2021_Count,
                                     'Jun 2021 Median': Jun_2021_Median})
RentCount_all_suburb
# Out:
#             Suburb  Jun 2021 Count  Jun 2021 Median
# 0      Albert Park             932              500
# 1      Middle Park             932              500
# 2    West St Kilda             932              500
# 3         Armadale             813              440
# 4    Carlton North             598              580
# ..             ...             ...              ...
# 210      Traralgon             831              345
# 211    Wanagaratta             574              330
# 212       Warragul             530              380
# 213    Warrnambool             857              360
# 214        Wodonga            1185              350
#
# [215 rows x 3 columns]

# %%
#While merging to avoid case sensitive issues
aus_lat_long['Suburb'] = aus_lat_long['Suburb'].str.lower()
RentCount_all_suburb['Suburb'] = RentCount_all_suburb['Suburb'].str.lower()

# %%
#Inner Join the two dataframes 
merged_inner = pd.merge(left=aus_lat_long, right=RentCount_all_suburb, 
                        left_on='Suburb', right_on='Suburb')

# %%
#Display the Rent values of June 2021 in all suburbs in Bubble Map
fig = px.scatter_geo(merged_inner, lat = 'lat', lon = 'long', 
                     hover_name="Suburb", size="Jun 2021 Median",
                     scope="world")
fig.show()
# Out:
# <div>                            <div id="8b658c72-230b-4c2a-b0f5-05b8ea2daa09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b658c72-230b-4c2a-b0f5-05b8ea2daa09")) {                    Plotly.newPlot(                        "8b658c72-230b-4c2a-b0f5-05b8ea2daa09",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Jun 2021 Median=%{marker.size}<br>lat=%{lat}<br>long=%{lon}<extra></extra>","hovertext":["kensington","kensington","kensington","kensington","kensington","kensington","epping","epping","epping","burwood","burwood","burwood","fairfield","fairfield","fairfield","fairfield","newtown","newtown","newtown","newtown","newtown","sydenham","sydenham","abbotsford","abbotsford","abbotsford","newport","newport","newport","cheltenham","cheltenham","cheltenham","cheltenham","croydon","croydon","croydon","croydon","canterbury","canterbury","carlton","carlton","carlton","sunshine","sunshine","belmont","belmont","belmont","belmont","belmont","hamilton","hamilton","hamilton","hamilton","hamilton","camberwell","camberwell","parkville","parkville","kew","kew","lilydale","lilydale","lilydale","lilydale","eltham","eltham","flinders","flinders","maffra","maffra","glenroy","glenroy","glenroy","glenroy","glenroy","ringwood","ringwood","ringwood","springvale","springvale","springvale","springvale","forest hill","forest hill","forest hill","forest hill","sebastopol","sebastopol","sebastopol","richmond","richmond","richmond","richmond","richmond","richmond","richmond","mulgrave","mulgrave","mulgrave","windsor","windsor","windsor","windsor","box hill","box hill","st albans","st albans","hampton","hampton","hampton","kangaroo flat","kangaroo flat","kangaroo flat","portland","portland","collingwood","collingwood","ivanhoe","ivanhoe","east melbourne","east melbourne","west melbourne","southbank","docklands","docklands","footscray","seddon","seddon","west footscray","yarraville","spotswood","williamstown","williamstown","williamstown","altona","altona","deer park","hoppers crossing","werribee","flemington","ascot vale","keilor east","avondale heights","keilor","moonee ponds","essendon","gladstone park","tullamarine","pascoe vale","pascoe vale south","oak park","broadmeadows","broadmeadows","north melbourne","carlton north","brunswick","brunswick","coburg","coburg north","fawkner","craigieburn","roxburgh park","fitzroy","fitzroy","clifton hill","clifton hill","fitzroy north","northcote","thornbury","preston","preston","preston","preston","reservoir","reservoir","thomastown","lalor","alphington","ivanhoe east","heidelberg west","mill park","bundoora","bundoora","heidelberg","greensborough","montmorency","research","hurstbridge","balwyn","bulleen","templestowe","doncaster","doncaster east","donvale","burnley","hawthorn","hawthorn","mont albert","surrey hills","blackburn","nunawading","mitcham","mitcham","vermont","south yarra","toorak","armadale","armadale","armadale","malvern","malvern","malvern east","glen iris","glen iris","ashburton","chadstone","mount waverley","glen waverley","burwood east","wantirna","bayswater","bayswater","bayswater","boronia","ferntree gully","caulfield","carnegie","murrumbeena","hughesdale","oakleigh","clayton","clayton","noble park","dandenong","dandenong","dandenong north","rowville","scoresby","prahran","st kilda","st kilda","st kilda","elwood","elsternwick","brighton","brighton","brighton","brighton","brighton east","beaumaris","beaumaris","mentone","aspendale","mordialloc","parkdale","chelsea","carrum","seaford","seaford","frankston","carrum downs","bentleigh","south melbourne","albert park","albert park","middle park","middle park","port melbourne","lara","corio","north geelong","grovedale","geelong west","herne hill","herne hill","geelong","ocean grov ...

# %% [markdown]
# ### Pearson Correlation

# %%
#Find the pearson correlation between last 10 columns of all properties data
headers_10 = headers [len(headers)-10:len(headers)]

df_all_new_10 = df_all_new[headers_10]
pcorr_all_df = df_all_new_10.corr(method='pearson')
pcorr_all = np.array(pcorr_all_df)
pcorr_all_round = np.around(pcorr_all, decimals=2)

fig6 = ff.create_annotated_heatmap(pcorr_all_round, 
                                   x=pcorr_all_df.index.to_list(), y=pcorr_all_df.columns.to_list())
fig6.show()
# Out:
# <div>                            <div id="f8e0c8ea-60c1-48ce-a921-dc3d9cd39b3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8e0c8ea-60c1-48ce-a921-dc3d9cd39b3b")) {                    Plotly.newPlot(                        "f8e0c8ea-60c1-48ce-a921-dc3d9cd39b3b",                        [{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"reversescale":false,"showscale":false,"type":"heatmap","x":["Jun 2020 Count","Jun 2020 Median","Sep 2020 Count","Sep 2020 Median","Dec 2020 Count","Dec 2020 Median","Mar 2021 Count","Mar 2021 Median","Jun 2021 Count","Jun 2021 Median"],"y":["Jun 2020 Count","Jun 2020 Median","Sep 2020 Count","Sep 2020 Median","Dec 2020 Count","Dec 2020 Median","Mar 2021 Count","Mar 2021 Median","Jun 2021 Count","Jun 2021 Median"],"z":[[1.0,0.03,1.0,0.01,1.0,-0.01,0.99,-0.04,0.99,-0.05],[0.03,1.0,0.04,0.99,0.05,0.98,0.06,0.95,0.07,0.91],[1.0,0.04,1.0,0.02,1.0,-0.01,0.99,-0.04,0.99,-0.05],[0.01,0.99,0.02,1.0,0.02,0.99,0.03,0.97,0.04,0.94],[1.0,0.05,1.0,0.02,1.0,-0.0,1.0,-0.03,1.0,-0.04],[-0.01,0.98,-0.01,0.99,-0.0,1.0,0.01,0.99,0.01,0.97],[0.99,0.06,0.99,0.03,1.0,0.01,1.0,-0.03,1.0,-0.04],[-0.04,0.95,-0.04,0.97,-0.03,0.99,-0.03,1.0,-0.02,0.99],[0.99,0.07,0.99,0.04,1.0,0.01,1.0,-0.02,1.0,-0.04],[-0.05,0.91,-0.05,0.94,-0.04,0.97,-0.04,0.99,-0.04,1.0]]}],                        {"annotations":[{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Jun 2020 Count","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.03","x":"Jun 2020 Median","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Sep 2020 Count","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.01","x":"Sep 2020 Median","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Dec 2020 Count","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.01","x":"Dec 2020 Median","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.99","x":"Mar 2021 Count","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.04","x":"Mar 2021 Median","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.99","x":"Jun 2021 Count","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.05","x":"Jun 2021 Median","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.03","x":"Jun 2020 Count","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Jun 2020 Median","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.04","x":"Sep 2020 Count","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.99","x":"Sep 2020 Median","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.05","x":"Dec 2020 Count","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.98","x":"Dec 2020 Median","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.06","x":"Mar 2021 Count","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#000000"},"showarrow":false, ...

# %% [markdown]
# ### Spearman Correlation

# %%
#Find the pearson correlation between last 10 columns of all properties data
scorr_all_df = df_all_new_10.corr(method='spearman')

scorr_all = np.array(scorr_all_df)
scorr_all_round = np.around(scorr_all, decimals=2)
fig6 = ff.create_annotated_heatmap(scorr_all_round, 
                                   x=scorr_all_df.index.to_list(), y=scorr_all_df.columns.to_list())
fig6.show()
# Out:
# <div>                            <div id="4b97bee8-6361-4453-8659-9812824ce71e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b97bee8-6361-4453-8659-9812824ce71e")) {                    Plotly.newPlot(                        "4b97bee8-6361-4453-8659-9812824ce71e",                        [{"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"reversescale":false,"showscale":false,"type":"heatmap","x":["Jun 2020 Count","Jun 2020 Median","Sep 2020 Count","Sep 2020 Median","Dec 2020 Count","Dec 2020 Median","Mar 2021 Count","Mar 2021 Median","Jun 2021 Count","Jun 2021 Median"],"y":["Jun 2020 Count","Jun 2020 Median","Sep 2020 Count","Sep 2020 Median","Dec 2020 Count","Dec 2020 Median","Mar 2021 Count","Mar 2021 Median","Jun 2021 Count","Jun 2021 Median"],"z":[[1.0,0.09,1.0,0.08,0.99,0.04,0.99,0.01,0.98,-0.02],[0.09,1.0,0.09,1.0,0.12,0.98,0.15,0.94,0.17,0.9],[1.0,0.09,1.0,0.07,1.0,0.04,0.99,0.0,0.99,-0.03],[0.08,1.0,0.07,1.0,0.1,0.99,0.13,0.96,0.15,0.92],[0.99,0.12,1.0,0.1,1.0,0.06,1.0,0.02,0.99,-0.01],[0.04,0.98,0.04,0.99,0.06,1.0,0.09,0.98,0.11,0.96],[0.99,0.15,0.99,0.13,1.0,0.09,1.0,0.05,1.0,0.01],[0.01,0.94,0.0,0.96,0.02,0.98,0.05,1.0,0.06,0.99],[0.98,0.17,0.99,0.15,0.99,0.11,1.0,0.06,1.0,0.02],[-0.02,0.9,-0.03,0.92,-0.01,0.96,0.01,0.99,0.02,1.0]]}],                        {"annotations":[{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Jun 2020 Count","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.09","x":"Jun 2020 Median","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Sep 2020 Count","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.08","x":"Sep 2020 Median","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.99","x":"Dec 2020 Count","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.04","x":"Dec 2020 Median","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.99","x":"Mar 2021 Count","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.01","x":"Mar 2021 Median","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.98","x":"Jun 2021 Count","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.02","x":"Jun 2021 Median","xref":"x","y":"Jun 2020 Count","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.09","x":"Jun 2020 Count","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Jun 2020 Median","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.09","x":"Sep 2020 Count","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Sep 2020 Median","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.12","x":"Dec 2020 Count","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.98","x":"Dec 2020 Median","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.15","x":"Mar 2021 Count","xref":"x","y":"Jun 2020 Median","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.94","x":"Mar 2 ...

# %% [markdown]
# ### Folium

# %%
#Display the number of houses in June 2021 in all suburbs using folium
map_aus = folium.Map([-25.2744, 133.7751], zoom_start=3.5, tiles = 'Stamen Terrain')

# %%
for index, row in merged_inner.iterrows():
    folium.Marker([row['lat'], row['long']],
              popup=row['Jun 2021 Count'],
              tooltip=row['Suburb'],              
             ).add_to(map_aus)

# %%
map_aus
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.5.1/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.5.1/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c42f52a9202144d281677fd10de33205%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c42f52a9202144d281677fd10de33205%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c42f52a9202144d281677fd10de33205%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c42f52a9202144d281677fd10de33205%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-25.2744%2C%20133.7751%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
